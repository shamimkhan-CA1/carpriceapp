# %% [markdown]
# # pandas ? - Panel Data - it's a largest data wrangling module in python

# %%
import pandas as pd

# %%
df=pd.read_csv("car price.csv")

# %%
df
# Out:
#                 Car Model  Mileage  Sell Price($)  Age(yrs)
# 0                  BMW X5    69000          18000         6
# 1                  BMW X5    35000          34000         3
# 2                  BMW X5    57000          26100         5
# 3                  BMW X5    22500          40000         2
# 4                  BMW X5    46000          31500         4
# 5                 Audi A5    59000          29400         5
# 6                 Audi A5    52000          32000         5
# 7                 Audi A5    72000          19300         6
# 8                 Audi A5    91000          12000         8
# 9   Mercedez Benz C class    67000          22000         6
# 10  Mercedez Benz C class    83000          20000         7
# 11  Mercedez Benz C class    79000          21000         7
# 12  Mercedez Benz C class    59000          33000         5

# %%
# Slope formula : y = MX + C  y= dependent variable  ( the variable you're going to predict ), 
# M= The slope, gradient of variable or the line 
# X = Independent variable (wo features / columns/ parameters jiske basis pr prediction hogi)
# c = The y-itercept, Which is the point where the line crosses the y-axis . This occurs when x = 0, so the coordinates of the intercept are
#(0,c)

# %%
#Basic EDA

# %%
df.shape
# Out:
# (13, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13 entries, 0 to 12
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car Model      13 non-null     object
#  1   Mileage        13 non-null     int64
#  2   Sell Price($)  13 non-null     int64
#  3   Age(yrs)       13 non-null     int64
# dtypes: int64(3), object(1)
# memory usage: 548.0+ bytes

# %%
df.describe()
# Out:
#             Mileage  Sell Price($)   Age(yrs)
# count     13.000000      13.000000  13.000000
# mean   60884.615385   26023.076923   5.307692
# std    19185.665055    8003.661021   1.652504
# min    22500.000000   12000.000000   2.000000
# 25%    52000.000000   20000.000000   5.000000
# 50%    59000.000000   26100.000000   5.000000
# 75%    72000.000000   32000.000000   6.000000
# max    91000.000000   40000.000000   8.000000

# %%
df.isnull().sum()
# Out:
# Car Model        0
# Mileage          0
# Sell Price($)    0
# Age(yrs)         0
# dtype: int64

# %%
df['Car Model'].value_counts()
# Out:
# Car Model
# BMW X5                   5
# Audi A5                  4
# Mercedez Benz C class    4
# Name: count, dtype: int64

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.0.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import seaborn as sns # statistical visualization module/package in python

# %%
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Car Model', 'Mileage', 'Sell Price($)', 'Age(yrs)'], dtype='object')

# %%
df2=df[['Mileage', 'Sell Price($)', 'Age(yrs)']]

# %%
df2
# Out:
#     Mileage  Sell Price($)  Age(yrs)
# 0     69000          18000         6
# 1     35000          34000         3
# 2     57000          26100         5
# 3     22500          40000         2
# 4     46000          31500         4
# 5     59000          29400         5
# 6     52000          32000         5
# 7     72000          19300         6
# 8     91000          12000         8
# 9     67000          22000         6
# 10    83000          20000         7
# 11    79000          21000         7
# 12    59000          33000         5

# %%
df2.corr()
# Out:
#                 Mileage  Sell Price($)  Age(yrs)
# Mileage        1.000000      -0.927116  0.993452
# Sell Price($) -0.927116       1.000000 -0.921741
# Age(yrs)       0.993452      -0.921741  1.000000

# %%
sns.heatmap(df2.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Data Preprocessing

# %%
#label encode - encode categorical values into number by assigning 0 to and onwards

# %%
# !pip install scikit-learn #largest library in python for Text base Machine Learning activities
# Out:
# ...
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    - -------------------------------------- 0.3/8.1 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/8.1 MB 390.3 kB/s eta 0:00:20
#    -- ------------------------------------- 0.5/8.1 MB 390.3 kB/s eta 0:00:20
#    -- ------------------------------------- 0.5/8.1 MB 390.3 kB/s eta 0:00:20
#    --- ------------------------------------ 0.8/8.1 MB 429.2 kB/s eta 0:00:18
#    --- ------------------------------------ 0.8/8.1 MB 429.2 kB/s eta 0:00:18
#    --- ------------------------------------ 0.8/8.1 MB 429.2 kB/s eta 0:00:18
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder() #creating object

# %%
df['Car Model']=le.fit_transform(df['Car Model'])

# %%
df
# Out:
#     Car Model  Mileage  Sell Price($)  Age(yrs)
# 0           1    69000          18000         6
# 1           1    35000          34000         3
# 2           1    57000          26100         5
# 3           1    22500          40000         2
# 4           1    46000          31500         4
# 5           0    59000          29400         5
# 6           0    52000          32000         5
# 7           0    72000          19300         6
# 8           0    91000          12000         8
# 9           2    67000          22000         6
# 10          2    83000          20000         7
# 11          2    79000          21000         7
# 12          2    59000          33000         5

# %%
le.classes_
# Out:
# array(['Audi A5', 'BMW X5', 'Mercedez Benz C class'], dtype=object)

# %%
x=df.drop("Sell Price($)", axis=1)

# %%
x
# Out:
#     Car Model  Mileage  Age(yrs)
# 0           1    69000         6
# 1           1    35000         3
# 2           1    57000         5
# 3           1    22500         2
# 4           1    46000         4
# 5           0    59000         5
# 6           0    52000         5
# 7           0    72000         6
# 8           0    91000         8
# 9           2    67000         6
# 10          2    83000         7
# 11          2    79000         7
# 12          2    59000         5

# %%
y=df["Sell Price($)"]

# %%
y
# Out:
# 0     18000
# 1     34000
# 2     26100
# 3     40000
# 4     31500
# 5     29400
# 6     32000
# 7     19300
# 8     12000
# 9     22000
# 10    20000
# 11    21000
# 12    33000
# Name: Sell Price($), dtype: int64

# %%
type(x)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series
